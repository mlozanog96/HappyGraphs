# %%
import pandas as pd

# %%
# Read in csv
df = pd.read_csv('/Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/Big Data/Big Data Project 4/HappyGraphs/app/world_bank_data.csv')

# %%
# Show columns
df.columns
# Out:
# Index(['country', 'date', 'indicator_name', 'value'], dtype='object')

# %%
# Pivotize data
df = df.pivot(index=['country', 'date'], columns='indicator_name', values='value').reset_index()

# %%
# Remove whitespaces from column names
df = df.rename(columns=lambda x: x.strip())

# %%
df
# Out:
# indicator_name      country  date
# 0               Afghanistan  1960  \
# 1               Afghanistan  1961
# 2               Afghanistan  1962
# 3               Afghanistan  1963
# 4               Afghanistan  1964
# ...                     ...   ...
# 16412              Zimbabwe  2017
# 16413              Zimbabwe  2018
# 16414              Zimbabwe  2019
# 16415              Zimbabwe  2020
# 16416              Zimbabwe  2021
#
# indicator_name  Access to clean fuels and technologies for cooking
# 0                                                             NaN   \
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 16412                                                        29.8
# 16413                                                        29.9
# 16414                                                        30.1
# 16415                                                        30.4
# 16416                                                         NaN
#
# indicator_name  Access to electricity  Agricultural methane emissions
# 0                                 NaN                             NaN  \
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ...                               ...                             ...
# 16412                       44.178635                        6246.328
# 16413                       45.572647                        6416.155
# 16414                       46.781475                        6535.140
# 16415                       52.747669                             NaN
# 16416                             NaN                             NaN
#
# indicator_name  CO2 emissions  Energy use  Forest area
# 0                         NaN         NaN          NaN  \
# 1                         NaN         NaN          NaN
# 2                         NaN         NaN          NaN
# 3                         NaN         NaN          NaN
# 4                         NaN         NaN          NaN
# ...                       ...         ...          ...
# 16412                0.700660         NaN    45.451183
# 16413                0.822618         NaN    45.332093
# 16414                0.765887         NaN    45.213002
# 16415                     NaN         NaN    45.093912
# 16416                     NaN         NaN          NaN
#
# indicator_name  GDP growth % mostly above 0 (but decreasing)   Inflation  ...
# 0                                                        NaN         NaN  ...  \
# 1                                                        NaN         NaN  ...
# 2                                                        NaN         NaN  ...
# 3                                                        NaN         NaN  ...
# 4                                                        NaN         NaN  ...
# ...                                                      ...         ...  ...
# 16412                                               4.080264    0.893962  ...
# 16413                                               5.009867   10.618866  ...
# 16414                                              -6.332446  255.304991  ...
# 16415                                              -7.816951  557.201817  ...
# 16416                                               8.468017   98.546105  ...
#
# indicator_name  Proportion of seats held by women in national parliaments
# 0                                                             NaN          \
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 16412                                                   32.575758
# 16413                                                   31.481481
# 16414                                                   31.851852
# 16415                                                   31.851852
# 16416                                                   31.851852
#
# indicator_name  Refugee population  Renewable energy consumption % stagnates
# 0                              NaN                                       NaN  \
# 1                              NaN                                       NaN
# 2                              NaN                                       NaN
# 3                              NaN                                       NaN
# 4                              NaN                                       NaN
# ...                            ...                                       ...
# 16412                       7566.0                                     82.46
# 16413                       7795.0                                     80.23
# 16414                       8956.0                                     81.50
# 16415                       9261.0                                       NaN
# 16416                       9483.0                                       NaN
#
# indicator_name  Sanitation service  Scientific technical journal articles
# 0                              NaN                                    NaN  \
# 1                              NaN                                    NaN
# 2                              NaN                                    NaN
# 3                              NaN                                    NaN
# 4                              NaN                                    NaN
# ...                            ...                                    ...
# 16412                    36.941673                                 334.71
# 16413                    36.357160                                 406.23
# 16414                    35.774337                                 431.62
# 16415                    35.192363                                 480.16
# 16416                          NaN                                    NaN
#
# indicator_name  Suicides  Total greenhouse gas emissions
# 0                    NaN                             NaN  \
# 1                    NaN                             NaN
# 2                    NaN                             NaN
# 3                    NaN                             NaN
# 4                    NaN                             NaN
# ...                  ...                             ...
# 16412               15.0                             NaN
# 16413               14.0                             NaN
# 16414               14.1                             NaN
# 16415                NaN                             NaN
# 16416                NaN                             NaN
#
# indicator_name  Vulnerable employment female  Vulnerable employment male
# 0                                        NaN                         NaN  \
# 1                                        NaN                         NaN
# 2                                        NaN                         NaN
# 3                                        NaN                         NaN
# 4                                        NaN                         NaN
# ...                                      ...                         ...
# 16412                              76.110930                   55.602293
# 16413                              75.989536                   55.486752
# 16414                              76.875290                   57.563610
# 16415                              77.471420                   58.673250
# 16416                              77.000920                   58.140974
#
# indicator_name  Vulnerable employment, total
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 16412                              66.126852
# 16413                              66.002542
# 16414                              67.463783
# 16415                              68.249560
# 16416                              67.732266
#
# [16417 rows x 28 columns]

# %%
# Drop columns with to many Nulls
#df.drop(['Tobacco use', 'Births attended by skilled health staff', 'Poverty gap', 'Marine protected areas', 'Urban land area', 'Literacy rate'], axis=1, inplace=True)

# %%
# Delete data for the year 2022 because there is nearly no data 
df = df[df['date'] < 2022]

# %%
# Restructuring the df
df_restructured = pd.melt(df, id_vars=['country', 'date'], var_name='indicator_name', value_name='value')

# %%
# Print data
df_restructured
# Out:
#             country  date                                     indicator_name
# 0       Afghanistan  1960  Access to clean fuels and technologies for coo...  \
# 1       Afghanistan  1961  Access to clean fuels and technologies for coo...
# 2       Afghanistan  1962  Access to clean fuels and technologies for coo...
# 3       Afghanistan  1963  Access to clean fuels and technologies for coo...
# 4       Afghanistan  1964  Access to clean fuels and technologies for coo...
# ...             ...   ...                                                ...
# 426837     Zimbabwe  2017                       Vulnerable employment, total
# 426838     Zimbabwe  2018                       Vulnerable employment, total
# 426839     Zimbabwe  2019                       Vulnerable employment, total
# 426840     Zimbabwe  2020                       Vulnerable employment, total
# 426841     Zimbabwe  2021                       Vulnerable employment, total
#
#             value
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 426837  66.126852
# 426838  66.002542
# 426839  67.463783
# 426840  68.249560
# 426841  67.732266
#
# [426842 rows x 4 columns]

# %% [markdown]
# # Data cleaning in four steps

# %% [markdown]
# # First cleaning step
# delete indicators for countries if there are less then 10 entries

# %%
# List of all indicators 
indicators = df_restructured['indicator_name'].unique()

# List of all countries
countries = df_restructured['country'].unique()

# %%
# Dictionary to store which countriy indicators have been deleted 
country_del_indicators = []

# Loop over all countries and indicators
for country in countries:
    for indicator in indicators:

        # Count not NA's for a countries indicator
        not_null_count = df_restructured.loc[(df_restructured["country"] == country) & (df_restructured["indicator_name"] == indicator), "value"].count()

        # If there are less then 10 datapoints delete indicator for country
        if not_null_count < 10: 
            # Create a string for the deleted country indicator
            country_indi = country + '_' + indicator
            # Store deleted country indicator 
            country_del_indicators = country_del_indicators + [country_indi]
           
            # Remove the rows corresponding to the indicator for the country
            df_restructured = df_restructured.loc[(df_restructured["country"] != country) | (df_restructured["indicator_name"] != indicator)]

# %%
# Show deleted indicators for country
country_del_indicators
# Out:
# ['Afghanistan_Energy use',
#  'Africa Eastern and Southern_Scientific technical journal articles',
#  'Africa Eastern and Southern_Total greenhouse gas emissions',
#  'Africa Western and Central_Scientific technical journal articles',
#  'Africa Western and Central_Total greenhouse gas emissions',
#  'American Samoa_Access to clean fuels and technologies for cooking',
#  'American Samoa_Access to electricity',
#  'American Samoa_Agricultural methane emissions',
#  'American Samoa_CO2 emissions',
#  'American Samoa_Energy use',
#  'American Samoa_Inflation',
#  'American Samoa_Labor force female',
#  'American Samoa_Labor force total',
#  'American Samoa_Life expectancy',
#  'American Samoa_Military expenditure',
#  'American Samoa_Mortality caused by road traffic',
#  'American Samoa_Proportion of seats held by women in national parliaments',
#  'American Samoa_Refugee population',
#  'American Samoa_Scientific technical journal articles',
#  'American Samoa_Suicides',
#  'American Samoa_Vulnerable employment female',
#  'American Samoa_Vulnerable employment male',
#  'American Samoa_Vulnerable employment, total',
#  'Andorra_Energy use',
#  'Andorra_Inflation',
#  'Andorra_Labor force female',
#  'Andorra_Labor force total',
#  'Andorra_Life expectancy',
#  'Andorra_Military expenditure',
#  'Andorra_Mortality caused by road traffic',
#  'Andorra_Refugee population',
#  'Andorra_Suicides',
#  'Andorra_Total greenhouse gas emissions',
#  'Andorra_Vulnerable employment female',
#  'Andorra_Vulnerable employment male',
#  'Andorra_Vulnerable employment, total',
#  'Antigua and Barbuda_Energy use',
#  'Antigua and Barbuda_Labor force female',
#  'Antigua and Barbuda_Labor force total',
#  'Antigua and Barbuda_Military expenditure',
#  'Antigua and Barbuda_Refugee population',
#  'Antigua and Barbuda_Vulnerable employment female',
#  'Antigua and Barbuda_Vulnerable employment male',
#  'Antigua and Barbuda_Vulnerable employment, total',
#  'Arab World_Scientific technical journal articles',
#  'Argentina_Inflation',
#  'Argentina_Open defecation',
#  'Aruba_Access to clean fuels and technologies for cooking',
#  'Aruba_Agricultural methane emissions',
#  'Aruba_CO2 emissions',
#  'Aruba_Energy use',
#  'Aruba_Labor force female',
#  'Aruba_Labor force total',
#  'Aruba_Military expenditure',
#  'Aruba_Mortality caused by road traffic',
#  'Aruba_Proportion of seats held by women in national parliaments',
#  'Aruba_Refugee population',
#  'Aruba_Scientific technical journal articles',
#  'Aruba_Suicides',
#  'Aruba_Total greenhouse gas emissions',
#  'Aruba_Vulnerable employment female',
#  'Aruba_Vulnerable employment male',
#  'Aruba_Vulnerable employment, total',
#  'Bahamas, The_Energy use',
#  'Bahamas, The_Military expenditure',
#  'Barbados_Energy use',
#  'Barbados_Military expenditure',
#  'Barbados_Refugee population',
#  'Belize_Energy use',
#  'Bermuda_Access to clean fuels and technologies for cooking',
#  'Bermuda_Agricultural methane emissions',
#  'Bermuda_CO2 emissions',
#  'Bermuda_Energy use',
#  'Bermuda_Inflation',
#  'Bermuda_Labor force female',
#  'Bermuda_Labor force total',
#  'Bermuda_Military expenditure',
#  'Bermuda_Mortality caused by road traffic',
#  'Bermuda_Proportion of seats held by women in national parliaments',
#  'Bermuda_Refugee population',
#  'Bermuda_Scientific technical journal articles',
#  'Bermuda_Suicides',
#  'Bermuda_Vulnerable employment female',
#  'Bermuda_Vulnerable employment male',
#  'Bermuda_Vulnerable employment, total',
#  'Bhutan_Energy use',
#  'Bhutan_Military expenditure',
#  'Bhutan_Refugee population',
#  'British Virgin Islands_Access to clean fuels and technologies for cooking',
#  'British Virgin Islands_Agricultural methane emissions',
#  'British Virgin Islands_CO2 emissions',
#  'British Virgin Islands_Energy use',
#  'British Virgin Islands_GDP growth % mostly above 0 (but decreasing)',
#  'British Virgin Islands_Inflation',
#  'British Virgin Islands_Labor force female',
#  'British Virgin Islands_Labor force total',
#  'British Virgin Islands_Military expenditure',
#  'British Virgin Islands_Mortality caused by road traffic',
#  'British Virgin Islands_Proportion of seats held by women in national parliaments',
#  'British Virgin Islands_Refugee population',
#  'British Virgin Islands_Scientific technical journal articles',
#  'British Virgin Islands_Suicides',
#  'British Virgin Islands_Total greenhouse gas emissions',
#  'British Virgin Islands_Vulnerable employment female',
#  'British Virgin Islands_Vulnerable employment male',
#  'British Virgin Islands_Vulnerable employment, total',
#  'Brunei Darussalam_Open defecation',
#  'Brunei Darussalam_Proportion of seats held by women in national parliaments',
#  'Brunei Darussalam_Refugee population',
#  'Brunei Darussalam_Sanitation service',
#  'Burkina Faso_Energy use',
#  'Burundi_Energy use',
#  'Cabo Verde_Energy use',
#  'Cabo Verde_Refugee population',
#  'Caribbean small states_Military expenditure',
#  'Caribbean small states_Scientific technical journal articles',
#  'Cayman Islands_Access to clean fuels and technologies for cooking',
#  'Cayman Islands_Agricultural methane emissions',
#  'Cayman Islands_CO2 emissions',
#  'Cayman Islands_Energy use',
#  'Cayman Islands_GDP growth % mostly above 0 (but decreasing)',
#  'Cayman Islands_Inflation',
#  'Cayman Islands_Labor force female',
#  'Cayman Islands_Labor force total',
#  'Cayman Islands_Life expectancy',
#  'Cayman Islands_Military expenditure',
#  'Cayman Islands_Mortality caused by road traffic',
#  'Cayman Islands_Proportion of seats held by women in national parliaments',
#  'Cayman Islands_Refugee population',
#  'Cayman Islands_Scientific technical journal articles',
#  'Cayman Islands_Suicides',
#  'Cayman Islands_Total greenhouse gas emissions',
#  'Cayman Islands_Vulnerable employment female',
#  'Cayman Islands_Vulnerable employment male',
#  'Cayman Islands_Vulnerable employment, total',
#  'Central African Republic_Energy use',
#  'Central Europe and the Baltics_Scientific technical journal articles',
#  'Chad_Energy use',
#  'Channel Islands_Access to clean fuels and technologies for cooking',
#  'Channel Islands_Agricultural methane emissions',
#  'Channel Islands_CO2 emissions',
#  'Channel Islands_Energy use',
#  'Channel Islands_GDP growth % mostly above 0 (but decreasing)',
#  'Channel Islands_Inflation',
#  'Channel Islands_Military expenditure',
#  'Channel Islands_Mortality caused by road traffic',
#  'Channel Islands_Open defecation',
#  'Channel Islands_People using at least basic drinking water services',
#  'Channel Islands_Population density',
#  'Channel Islands_Proportion of seats held by women in national parliaments',
#  'Channel Islands_Refugee population',
#  'Channel Islands_Renewable energy consumption % stagnates',
#  'Channel Islands_Sanitation service',
#  'Channel Islands_Scientific technical journal articles',
#  'Channel Islands_Suicides',
#  'Channel Islands_Total greenhouse gas emissions',
#  'Comoros_Energy use',
#  'Comoros_Military expenditure',
#  'Comoros_Refugee population',
#  'Costa Rica_Military expenditure',
#  'Croatia_People using at least basic drinking water services',
#  'Cuba_Inflation',
#  'Cuba_Military expenditure',
#  'Curacao_Access to clean fuels and technologies for cooking',
#  'Curacao_Agricultural methane emissions',
#  'Curacao_CO2 emissions',
#  'Curacao_Labor force female',
#  'Curacao_Labor force total',
#  'Curacao_Military expenditure',
#  'Curacao_Mortality caused by road traffic',
#  'Curacao_Proportion of seats held by women in national parliaments',
#  'Curacao_Scientific technical journal articles',
#  'Curacao_Suicides',
#  'Curacao_Total greenhouse gas emissions',
#  'Curacao_Vulnerable employment female',
#  'Curacao_Vulnerable employment male',
#  'Curacao_Vulnerable employment, total',
#  'Djibouti_Energy use',
#  'Djibouti_GDP growth % mostly above 0 (but decreasing)',
#  'Dominica_Energy use',
#  'Dominica_Labor force female',
#  'Dominica_Labor force total',
#  'Dominica_Military expenditure',
#  'Dominica_Mortality caused by road traffic',
#  'Dominica_Refugee population',
#  'Dominica_Suicides',
#  'Dominica_Vulnerable employment female',
#  'Dominica_Vulnerable employment male',
#  'Dominica_Vulnerable employment, total',
#  'Early-demographic dividend_Scientific technical journal articles',
#  'East Asia & Pacific_Scientific technical journal articles',
#  'East Asia & Pacific (IDA & IBRD countries)_Scientific technical journal articles',
#  'East Asia & Pacific (excluding high income)_Scientific technical journal articles',
#  'Equatorial Guinea_Energy use',
#  'Equatorial Guinea_Refugee population',
#  'Eritrea_Inflation',
#  'Eritrea_Military expenditure',
#  'Eswatini_Energy use',
#  'Euro area_Scientific technical journal articles',
#  'Europe & Central Asia_Scientific technical journal articles',
#  'Europe & Central Asia (IDA & IBRD countries)_Scientific technical journal articles',
#  'Europe & Central Asia (excluding high income)_Scientific technical journal articles',
#  'European Union_Scientific technical journal articles',
#  'Faroe Islands_Access to clean fuels and technologies for cooking',
#  'Faroe Islands_Agricultural methane emissions',
#  'Faroe Islands_CO2 emissions',
#  'Faroe Islands_Energy use',
#  'Faroe Islands_GDP growth % mostly above 0 (but decreasing)',
#  'Faroe Islands_Inflation',
#  'Faroe Islands_Labor force female',
#  'Faroe Islands_Labor force total',
#  'Faroe Islands_Military expenditure',
#  'Faroe Islands_Mortality caused by road traffic',
#  'Faroe Islands_Open defecation',
#  'Faroe Islands_Proportion of seats held by women in national parliaments',
#  'Faroe Islands_Refugee population',
#  'Faroe Islands_Sanitation service',
#  'Faroe Islands_Scientific technical journal articles',
#  'Faroe Islands_Suicides',
#  'Faroe Islands_Total greenhouse gas emissions',
#  'Faroe Islands_Vulnerable employment female',
#  'Faroe Islands_Vulnerable employment male',
#  'Faroe Islands_Vulnerable employment, total',
#  'Fiji_Energy use',
#  'Fragile and conflict affected situations_Scientific technical journal articles',
#  'French Polynesia_Access to clean fuels and technologies for cooking',
#  'French Polynesia_Agricultural methane emissions',
#  'French Polynesia_CO2 emissions',
#  'French Polynesia_Energy use',
#  'French Polynesia_Inflation',
#  'French Polynesia_Military expenditure',
#  'French Polynesia_Mortality caused by road traffic',
#  'French Polynesia_Proportion of seats held by women in national parliaments',
#  'French Polynesia_Refugee population',
#  'French Polynesia_Scientific technical journal articles',
#  'French Polynesia_Suicides',
#  'Gambia, The_Energy use',
#  'Gibraltar_Access to clean fuels and technologies for cooking',
#  'Gibraltar_Agricultural methane emissions',
#  'Gibraltar_CO2 emissions',
#  'Gibraltar_GDP growth % mostly above 0 (but decreasing)',
#  'Gibraltar_Inflation',
#  'Gibraltar_Labor force female',
#  'Gibraltar_Labor force total',
#  'Gibraltar_Military expenditure',
#  'Gibraltar_Mortality caused by road traffic',
#  'Gibraltar_Proportion of seats held by women in national parliaments',
#  'Gibraltar_Refugee population',
#  'Gibraltar_Scientific technical journal articles',
#  'Gibraltar_Suicides',
#  'Gibraltar_Vulnerable employment female',
#  'Gibraltar_Vulnerable employment male',
#  'Gibraltar_Vulnerable employment, total',
#  'Greenland_Access to clean fuels and technologies for cooking',
#  'Greenland_Agricultural methane emissions',
#  'Greenland_CO2 emissions',
#  'Greenland_Energy use',
#  'Greenland_Inflation',
#  'Greenland_Labor force female',
#  'Greenland_Labor force total',
#  'Greenland_Military expenditure',
#  'Greenland_Mortality caused by road traffic',
#  'Greenland_Proportion of seats held by women in national parliaments',
#  'Greenland_Refugee population',
#  'Greenland_Suicides',
#  'Greenland_Total greenhouse gas emissions',
#  'Greenland_Vulnerable employment female',
#  'Greenland_Vulnerable employment male',
#  'Greenland_Vulnerable employment, total',
#  'Grenada_Energy use',
#  'Grenada_Labor force female',
#  'Grenada_Labor force total',
#  'Grenada_Military expenditure',
#  'Grenada_Refugee population',
#  'Grenada_Vulnerable employment female',
#  'Grenada_Vulnerable employment male',
#  'Grenada_Vulnerable employment, total',
#  'Guam_Access to clean fuels and technologies for cooking',
#  'Guam_Agricultural methane emissions',
#  'Guam_CO2 emissions',
#  'Guam_Energy use',
#  'Guam_Inflation',
#  'Guam_Military expenditure',
#  'Guam_Mortality caused by road traffic',
#  'Guam_Proportion of seats held by women in national parliaments',
#  'Guam_Refugee population',
#  'Guam_Scientific technical journal articles',
#  'Guam_Suicides',
#  'Guinea_Energy use',
#  'Guinea-Bissau_Energy use',
#  'Guyana_Energy use',
#  'Haiti_Refugee population',
#  'Heavily indebted poor countries (HIPC)_Energy use',
#  'Heavily indebted poor countries (HIPC)_Scientific technical journal articles',
#  'High income_Scientific technical journal articles',
#  'Hong Kong SAR, China_Access to clean fuels and technologies for cooking',
#  'Hong Kong SAR, China_Agricultural methane emissions',
#  'Hong Kong SAR, China_CO2 emissions',
#  'Hong Kong SAR, China_Forest area',
#  'Hong Kong SAR, China_Military expenditure',
#  'Hong Kong SAR, China_Mortality caused by road traffic',
#  'Hong Kong SAR, China_Proportion of seats held by women in national parliaments',
#  'Hong Kong SAR, China_Scientific technical journal articles',
#  'Hong Kong SAR, China_Suicides',
#  'IBRD only_Scientific technical journal articles',
#  'IDA & IBRD total_Scientific technical journal articles',
#  'IDA blend_Scientific technical journal articles',
#  'IDA only_Scientific technical journal articles',
#  'IDA total_Scientific technical journal articles',
#  'Iceland_Military expenditure',
#  'Isle of Man_Access to clean fuels and technologies for cooking',
#  'Isle of Man_Agricultural methane emissions',
#  'Isle of Man_CO2 emissions',
#  'Isle of Man_Energy use',
#  'Isle of Man_Inflation',
#  'Isle of Man_Labor force female',
#  'Isle of Man_Labor force total',
#  'Isle of Man_Military expenditure',
#  'Isle of Man_Mortality caused by road traffic',
#  'Isle of Man_Open defecation',
#  'Isle of Man_Proportion of seats held by women in national parliaments',
#  'Isle of Man_Refugee population',
#  'Isle of Man_Sanitation service',
#  'Isle of Man_Scientific technical journal articles',
#  'Isle of Man_Suicides',
#  'Isle of Man_Total greenhouse gas emissions',
#  'Isle of Man_Vulnerable employment female',
#  'Isle of Man_Vulnerable employment male',
#  'Isle of Man_Vulnerable employment, total',
#  'Kiribati_Energy use',
#  'Kiribati_Labor force female',
#  'Kiribati_Labor force total',
#  'Kiribati_Military expenditure',
#  'Kiribati_Refugee population',
#  'Kiribati_Vulnerable employment female',
#  'Kiribati_Vulnerable employment male',
#  'Kiribati_Vulnerable employment, total',
#  "Korea, Dem. People's Rep._GDP growth % mostly above 0 (but decreasing)",
#  "Korea, Dem. People's Rep._Inflation",
#  "Korea, Dem. People's Rep._Military expenditure",
#  "Korea, Dem. People's Rep._Refugee population",
#  'Kosovo_Access to clean fuels and technologies for cooking',
#  'Kosovo_Agricultural methane emissions',
#  'Kosovo_CO2 emissions',
#  'Kosovo_Energy use',
#  'Kosovo_Forest area',
#  'Kosovo_GDP growth % mostly above 0 (but decreasing)',
#  'Kosovo_Labor force female',
#  'Kosovo_Labor force total',
#  'Kosovo_Mortality caused by road traffic',
#  'Kosovo_Open defecation',
#  'Kosovo_People using at least basic drinking water services',
#  'Kosovo_Population density',
#  'Kosovo_Proportion of seats held by women in national parliaments',
#  'Kosovo_Refugee population',
#  'Kosovo_Sanitation service',
#  'Kosovo_Suicides',
#  'Kosovo_Total greenhouse gas emissions',
#  'Kosovo_Vulnerable employment female',
#  'Kosovo_Vulnerable employment male',
#  'Kosovo_Vulnerable employment, total',
#  'Kuwait_Total greenhouse gas emissions',
#  'Lao PDR_Energy use',
#  'Late-demographic dividend_Scientific technical journal articles',
#  'Latin America & Caribbean_Scientific technical journal articles',
#  'Latin America & Caribbean (excluding high income)_Scientific technical journal articles',
#  'Latin America & the Caribbean (IDA & IBRD countries)_Scientific technical journal articles',
#  'Least developed countries: UN classification_Scientific technical journal articles',
#  'Lebanon_Access to clean fuels and technologies for cooking',
#  'Lebanon_Total greenhouse gas emissions',
#  'Lesotho_Energy use',
#  'Liberia_Energy use',
#  'Libya_Access to clean fuels and technologies for cooking',
#  'Liechtenstein_Access to clean fuels and technologies for cooking',
#  'Liechtenstein_Agricultural methane emissions',
#  'Liechtenstein_Energy use',
#  'Liechtenstein_Inflation',
#  'Liechtenstein_Labor force female',
#  'Liechtenstein_Labor force total',
#  'Liechtenstein_Military expenditure',
#  'Liechtenstein_Mortality caused by road traffic',
#  'Liechtenstein_Suicides',
#  'Liechtenstein_Total greenhouse gas emissions',
#  'Liechtenstein_Vulnerable employment female',
#  'Liechtenstein_Vulnerable employment male',
#  'Liechtenstein_Vulnerable employment, total',
#  'Low & middle income_Scientific technical journal articles',
#  'Low income_Energy use',
#  'Low income_Scientific technical journal articles',
#  'Lower middle income_Scientific technical journal articles',
#  'Macao SAR, China_Access to clean fuels and technologies for cooking',
#  'Macao SAR, China_Agricultural methane emissions',
#  'Macao SAR, China_CO2 emissions',
#  'Macao SAR, China_Energy use',
#  'Macao SAR, China_Forest area',
#  'Macao SAR, China_Military expenditure',
#  'Macao SAR, China_Mortality caused by road traffic',
#  'Macao SAR, China_Proportion of seats held by women in national parliaments',
#  'Macao SAR, China_Scientific technical journal articles',
#  'Macao SAR, China_Suicides',
#  'Macao SAR, China_Total greenhouse gas emissions',
#  'Madagascar_Energy use',
#  'Malawi_Energy use',
#  'Maldives_Energy use',
#  'Maldives_Military expenditure',
#  'Maldives_Refugee population',
#  'Maldives_Total greenhouse gas emissions',
#  'Mali_Energy use',
#  'Marshall Islands_Energy use',
#  'Marshall Islands_Inflation',
#  'Marshall Islands_Labor force female',
#  'Marshall Islands_Labor force total',
#  'Marshall Islands_Military expenditure',
#  'Marshall Islands_Mortality caused by road traffic',
#  'Marshall Islands_Refugee population',
#  'Marshall Islands_Suicides',
#  'Marshall Islands_Total greenhouse gas emissions',
#  'Marshall Islands_Vulnerable employment female',
#  'Marshall Islands_Vulnerable employment male',
#  'Marshall Islands_Vulnerable employment, total',
#  'Mauritania_Energy use',
#  'Mauritius_Refugee population',
#  'Mauritius_Total greenhouse gas emissions',
#  'Micronesia, Fed. Sts._Energy use',
#  'Micronesia, Fed. Sts._Labor force female',
#  'Micronesia, Fed. Sts._Labor force total',
#  'Micronesia, Fed. Sts._Military expenditure',
#  'Micronesia, Fed. Sts._Open defecation',
#  'Micronesia, Fed. Sts._Refugee population',
#  'Micronesia, Fed. Sts._Total greenhouse gas emissions',
#  'Micronesia, Fed. Sts._Vulnerable employment female',
#  'Micronesia, Fed. Sts._Vulnerable employment male',
#  'Micronesia, Fed. Sts._Vulnerable employment, total',
#  'Middle East & North Africa_Scientific technical journal articles',
#  'Middle East & North Africa (IDA & IBRD countries)_Scientific technical journal articles',
#  'Middle East & North Africa (excluding high income)_Scientific technical journal articles',
#  'Middle income_Scientific technical journal articles',
#  'Monaco_Agricultural methane emissions',
#  'Monaco_CO2 emissions',
#  'Monaco_Energy use',
#  'Monaco_Inflation',
#  'Monaco_Labor force female',
#  'Monaco_Labor force total',
#  'Monaco_Life expectancy',
#  'Monaco_Military expenditure',
#  'Monaco_Mortality caused by road traffic',
#  'Monaco_Renewable energy consumption % stagnates',
#  'Monaco_Suicides',
#  'Monaco_Total greenhouse gas emissions',
#  'Monaco_Vulnerable employment female',
#  'Monaco_Vulnerable employment male',
#  'Monaco_Vulnerable employment, total',
#  'Montenegro_Energy use',
#  'Montenegro_Total greenhouse gas emissions',
#  'Myanmar_Refugee population',
#  'Nauru_Energy use',
#  'Nauru_Inflation',
#  'Nauru_Labor force female',
#  'Nauru_Labor force total',
#  'Nauru_Military expenditure',
#  'Nauru_Mortality caused by road traffic',
#  'Nauru_Refugee population',
#  'Nauru_Suicides',
#  'Nauru_Total greenhouse gas emissions',
#  'Nauru_Vulnerable employment female',
#  'Nauru_Vulnerable employment male',
#  'Nauru_Vulnerable employment, total',
#  'New Caledonia_Access to clean fuels and technologies for cooking',
#  'New Caledonia_Agricultural methane emissions',
#  'New Caledonia_CO2 emissions',
#  'New Caledonia_Energy use',
#  'New Caledonia_Inflation',
#  'New Caledonia_Military expenditure',
#  'New Caledonia_Mortality caused by road traffic',
#  'New Caledonia_Proportion of seats held by women in national parliaments',
#  'New Caledonia_Refugee population',
#  'New Caledonia_Scientific technical journal articles',
#  'New Caledonia_Suicides',
#  'New Caledonia_Total greenhouse gas emissions',
#  'Niger_Energy use',
#  'North America_Scientific technical journal articles',
#  'Northern Mariana Islands_Access to clean fuels and technologies for cooking',
#  'Northern Mariana Islands_Agricultural methane emissions',
#  'Northern Mariana Islands_CO2 emissions',
#  'Northern Mariana Islands_Energy use',
#  'Northern Mariana Islands_Inflation',
#  'Northern Mariana Islands_Labor force female',
#  'Northern Mariana Islands_Labor force total',
#  'Northern Mariana Islands_Life expectancy',
#  'Northern Mariana Islands_Military expenditure',
#  'Northern Mariana Islands_Mortality caused by road traffic',
#  'Northern Mariana Islands_Proportion of seats held by women in national parliaments',
#  'Northern Mariana Islands_Refugee population',
#  'Northern Mariana Islands_Scientific technical journal articles',
#  'Northern Mariana Islands_Suicides',
#  'Northern Mariana Islands_Vulnerable employment female',
#  'Northern Mariana Islands_Vulnerable employment male',
#  'Northern Mariana Islands_Vulnerable employment, total',
#  'OECD members_Scientific technical journal articles',
#  'Other small states_Energy use',
#  'Other small states_Scientific technical journal articles',
#  'Pacific island small states_Energy use',
#  'Pacific island small states_Scientific technical journal articles',
#  'Palau_Energy use',
#  'Palau_Labor force female',
#  'Palau_Labor force total',
#  'Palau_Life expectancy',
#  'Palau_Military expenditure',
#  'Palau_Mortality caused by road traffic',
#  'Palau_Refugee population',
#  'Palau_Suicides',
#  'Palau_Total greenhouse gas emissions',
#  'Palau_Vulnerable employment female',
#  'Palau_Vulnerable employment male',
#  'Palau_Vulnerable employment, total',
#  'Papua New Guinea_Energy use',
#  'Post-demographic dividend_Scientific technical journal articles',
#  'Pre-demographic dividend_Scientific technical journal articles',
#  'Puerto Rico_Access to clean fuels and technologies for cooking',
#  'Puerto Rico_Agricultural methane emissions',
#  'Puerto Rico_CO2 emissions',
#  'Puerto Rico_Energy use',
#  'Puerto Rico_Inflation',
#  'Puerto Rico_Military expenditure',
#  'Puerto Rico_Mortality caused by road traffic',
#  'Puerto Rico_Proportion of seats held by women in national parliaments',
#  'Puerto Rico_Refugee population',
#  'Puerto Rico_Suicides',
#  'Rwanda_Energy use',
#  'Samoa_Energy use',
#  'Samoa_Military expenditure',
#  'Samoa_Refugee population',
#  'San Marino_Agricultural methane emissions',
#  'San Marino_CO2 emissions',
#  'San Marino_Energy use',
#  'San Marino_Labor force female',
#  'San Marino_Labor force total',
#  'San Marino_Life expectancy',
#  'San Marino_Military expenditure',
#  'San Marino_Mortality caused by road traffic',
#  'San Marino_Refugee population',
#  'San Marino_Renewable energy consumption % stagnates',
#  'San Marino_Suicides',
#  'San Marino_Total greenhouse gas emissions',
#  'San Marino_Vulnerable employment female',
#  'San Marino_Vulnerable employment male',
#  'San Marino_Vulnerable employment, total',
#  'Sao Tome and Principe_Energy use',
#  'Sao Tome and Principe_Military expenditure',
#  'Sao Tome and Principe_Refugee population',
#  'Saudi Arabia_Total greenhouse gas emissions',
#  'Serbia_Total greenhouse gas emissions',
#  'Seychelles_Energy use',
#  'Seychelles_Labor force female',
#  'Seychelles_Labor force total',
#  'Seychelles_Refugee population',
#  'Seychelles_Vulnerable employment female',
#  'Seychelles_Vulnerable employment male',
#  'Seychelles_Vulnerable employment, total',
#  'Sierra Leone_Energy use',
#  'Singapore_Total greenhouse gas emissions',
#  'Sint Maarten (Dutch part)_Access to clean fuels and technologies for cooking',
#  'Sint Maarten (Dutch part)_Agricultural methane emissions',
#  'Sint Maarten (Dutch part)_CO2 emissions',
#  'Sint Maarten (Dutch part)_Energy use',
#  'Sint Maarten (Dutch part)_GDP growth % mostly above 0 (but decreasing)',
#  'Sint Maarten (Dutch part)_Labor force female',
#  'Sint Maarten (Dutch part)_Labor force total',
#  'Sint Maarten (Dutch part)_Military expenditure',
#  'Sint Maarten (Dutch part)_Mortality caused by road traffic',
#  'Sint Maarten (Dutch part)_Proportion of seats held by women in national parliaments',
#  'Sint Maarten (Dutch part)_Refugee population',
#  'Sint Maarten (Dutch part)_Scientific technical journal articles',
#  'Sint Maarten (Dutch part)_Suicides',
#  'Sint Maarten (Dutch part)_Total greenhouse gas emissions',
#  'Sint Maarten (Dutch part)_Vulnerable employment female',
#  'Sint Maarten (Dutch part)_Vulnerable employment male',
#  'Sint Maarten (Dutch part)_Vulnerable employment, total',
#  'Small states_Energy use',
#  'Small states_Military expenditure',
#  'Small states_Scientific technical journal articles',
#  'Solomon Islands_Energy use',
#  'Solomon Islands_Military expenditure',
#  'Solomon Islands_Refugee population',
#  'Somalia_Energy use',
#  'Somalia_Inflation',
#  'South Asia_Scientific technical journal articles',
#  'South Asia (IDA & IBRD)_Scientific technical journal articles',
#  'South Sudan_Energy use',
#  'South Sudan_Forest area',
#  'South Sudan_GDP growth % mostly above 0 (but decreasing)',
#  'South Sudan_Population density',
#  'South Sudan_Renewable energy consumption % stagnates',
#  'South Sudan_Total greenhouse gas emissions',
#  'St. Kitts and Nevis_Energy use',
#  'St. Kitts and Nevis_Labor force female',
#  'St. Kitts and Nevis_Labor force total',
#  'St. Kitts and Nevis_Military expenditure',
#  'St. Kitts and Nevis_Mortality caused by road traffic',
#  'St. Kitts and Nevis_Refugee population',
#  'St. Kitts and Nevis_Suicides',
#  'St. Kitts and Nevis_Total greenhouse gas emissions',
#  'St. Kitts and Nevis_Vulnerable employment female',
#  'St. Kitts and Nevis_Vulnerable employment male',
#  'St. Kitts and Nevis_Vulnerable employment, total',
#  'St. Lucia_Energy use',
#  'St. Lucia_Military expenditure',
#  'St. Lucia_Refugee population',
#  'St. Martin (French part)_Access to clean fuels and technologies for cooking',
#  'St. Martin (French part)_Agricultural methane emissions',
#  'St. Martin (French part)_CO2 emissions',
#  'St. Martin (French part)_Energy use',
#  'St. Martin (French part)_GDP growth % mostly above 0 (but decreasing)',
#  'St. Martin (French part)_Inflation',
#  'St. Martin (French part)_Labor force female',
#  'St. Martin (French part)_Labor force total',
#  'St. Martin (French part)_Military expenditure',
#  'St. Martin (French part)_Mortality caused by road traffic',
#  'St. Martin (French part)_Population density',
#  'St. Martin (French part)_Proportion of seats held by women in national parliaments',
#  'St. Martin (French part)_Refugee population',
#  'St. Martin (French part)_Renewable energy consumption % stagnates',
#  'St. Martin (French part)_Scientific technical journal articles',
#  'St. Martin (French part)_Suicides',
#  'St. Martin (French part)_Total greenhouse gas emissions',
#  'St. Martin (French part)_Vulnerable employment female',
#  'St. Martin (French part)_Vulnerable employment male',
#  'St. Martin (French part)_Vulnerable employment, total',
#  'St. Vincent and the Grenadines_Energy use',
#  'St. Vincent and the Grenadines_Military expenditure',
#  'St. Vincent and the Grenadines_Refugee population',
#  'Sub-Saharan Africa_Scientific technical journal articles',
#  'Sub-Saharan Africa (IDA & IBRD countries)_Scientific technical journal articles',
#  'Sub-Saharan Africa (excluding high income)_Scientific technical journal articles',
#  'Suriname_Energy use',
#  'Suriname_Military expenditure',
#  'Suriname_Refugee population',
#  'Timor-Leste_Energy use',
#  'Timor-Leste_Refugee population',
#  'Tonga_Energy use',
#  'Tonga_Military expenditure',
#  'Tonga_Refugee population',
#  'Trinidad and Tobago_Total greenhouse gas emissions',
#  'Turkmenistan_Inflation',
#  'Turkmenistan_Military expenditure',
#  'Turks and Caicos Islands_Access to clean fuels and technologies for cooking',
#  'Turks and Caicos Islands_Agricultural methane emissions',
#  'Turks and Caicos Islands_CO2 emissions',
#  'Turks and Caicos Islands_Energy use',
#  'Turks and Caicos Islands_GDP growth % mostly above 0 (but decreasing)',
#  'Turks and Caicos Islands_Inflation',
#  'Turks and Caicos Islands_Labor force female',
#  'Turks and Caicos Islands_Labor force total',
#  'Turks and Caicos Islands_Military expenditure',
#  'Turks and Caicos Islands_Mortality caused by road traffic',
#  'Turks and Caicos Islands_Proportion of seats held by women in national parliaments',
#  'Turks and Caicos Islands_Refugee population',
#  'Turks and Caicos Islands_Scientific technical journal articles',
#  'Turks and Caicos Islands_Suicides',
#  'Turks and Caicos Islands_Total greenhouse gas emissions',
#  'Turks and Caicos Islands_Vulnerable employment female',
#  'Turks and Caicos Islands_Vulnerable employment male',
#  'Turks and Caicos Islands_Vulnerable employment, total',
#  'Tuvalu_Energy use',
#  'Tuvalu_Inflation',
#  'Tuvalu_Labor force female',
#  'Tuvalu_Labor force total',
#  'Tuvalu_Military expenditure',
#  'Tuvalu_Mortality caused by road traffic',
#  'Tuvalu_Refugee population',
#  'Tuvalu_Suicides',
#  'Tuvalu_Vulnerable employment female',
#  'Tuvalu_Vulnerable employment male',
#  'Tuvalu_Vulnerable employment, total',
#  'Uganda_Energy use',
#  'Upper middle income_Scientific technical journal articles',
#  'Uzbekistan_Inflation',
#  'Uzbekistan_Military expenditure',
#  'Vanuatu_Energy use',
#  'Vanuatu_Military expenditure',
#  'Vanuatu_Refugee population',
#  'Venezuela, RB_Inflation',
#  'Virgin Islands (U.S.)_Access to clean fuels and technologies for cooking',
#  'Virgin Islands (U.S.)_Agricultural methane emissions',
#  'Virgin Islands (U.S.)_CO2 emissions',
#  'Virgin Islands (U.S.)_Energy use',
#  'Virgin Islands (U.S.)_Inflation',
#  'Virgin Islands (U.S.)_Military expenditure',
#  'Virgin Islands (U.S.)_Mortality caused by road traffic',
#  'Virgin Islands (U.S.)_Proportion of seats held by women in national parliaments',
#  'Virgin Islands (U.S.)_Refugee population',
#  'Virgin Islands (U.S.)_Scientific technical journal articles',
#  'Virgin Islands (U.S.)_Suicides',
#  'West Bank and Gaza_Access to clean fuels and technologies for cooking',
#  'West Bank and Gaza_Agricultural methane emissions',
#  'West Bank and Gaza_CO2 emissions',
#  'West Bank and Gaza_Energy use',
#  'West Bank and Gaza_Military expenditure',
#  'West Bank and Gaza_Mortality caused by road traffic',
#  'West Bank and Gaza_Proportion of seats held by women in national parliaments',
#  'West Bank and Gaza_Suicides',
#  'West Bank and Gaza_Total greenhouse gas emissions',
#  'World_Scientific technical journal articles']

# %%
# Show Null values
df_restructured.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 383457 entries, 0 to 426841
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   country         383457 non-null  object
#  1   date            383457 non-null  int64
#  2   indicator_name  383457 non-null  object
#  3   value           199716 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 14.6+ MB

# %% [markdown]
# # Second cleaning step
# Clean columns accorinding to Big Data Project.xlsx sheet indicators. If there is not a lot of data in some years for a feature the nulls will be deleted

# %%
# Store copy
df_dels = df_restructured.copy()

# %%
df_dels.indicator_name.unique()
# Out:
# array(['Access to clean fuels and technologies for cooking',
#        'Access to electricity', 'Agricultural methane emissions',
#        'CO2 emissions', 'Energy use', 'Forest area',
#        'GDP growth % mostly above 0 (but decreasing)', 'Inflation',
#        'Labor force female', 'Labor force total', 'Life expectancy',
#        'Military expenditure', 'Mortality caused by road traffic',
#        'Open defecation',
#        'People using at least basic drinking water services',
#        'Population density',
#        'Proportion of seats held by women in national parliaments',
#        'Refugee population', 'Renewable energy consumption % stagnates',
#        'Sanitation service', 'Scientific technical journal articles',
#        'Suicides', 'Total greenhouse gas emissions',
#        'Vulnerable employment female', 'Vulnerable employment male',
#        'Vulnerable employment, total'], dtype=object)

# %%
# Drop Null rows for People using at least basic drinking water services year, suicides, open defecation sanitation service before 2000
df_dels.drop(df_dels.loc[((df_dels["indicator_name"] == 'People using at least basic drinking water services') | 
                          (df_dels["indicator_name"] == 'Suicides') | 
                          (df_dels["indicator_name"] == 'Open defecation') | 
                          (df_dels["indicator_name"] == 'Sanitation service')) & 
                         (df_dels["date"] < 2000) & 
                         df_dels["value"].isnull()].index, inplace=True)

# Drop Null rows for Vulnerable employment indicators before 1991
df_dels.drop(df_dels.loc[((df_dels["indicator_name"] == 'Vulnerable employment male') | 
                          (df_dels["indicator_name"] == 'Vulnerable employment female') | 
                          ((df_dels["indicator_name"] == 'Vulnerable employment, total') & 
                           (df_dels["date"] < 1991))) & 
                           df_dels["value"].isnull()].index, inplace=True)

# Drop Null rows for inflation  before 1984
df_dels.drop(df_dels.loc[(((df_dels["indicator_name"] == 'Inflation') &
                           (df_dels["date"] < 1984))) & 
                           df_dels["value"].isnull()].index, inplace=True)


# Drop Null rows for GDP growth  before 71
df_dels.drop(df_dels.loc[(((df_dels["indicator_name"] == 'GDP growth % mostly above 0 (but decreasing)') &
                           (df_dels["date"] < 1971))) & 
                           df_dels["value"].isnull()].index, inplace=True)



# Drop Null rows for Labor force indicators before 1989
df_dels.drop(df_dels.loc[((df_dels["indicator_name"] == 'Labor force total') | 
                          ((df_dels["indicator_name"] == 'Labor force female') & 
                           (df_dels["date"] < 1991))) & 
                           df_dels["value"].isnull()].index, inplace=True)

# Drop Null rows for Military expentiture force indicators before 1981
df_dels.drop(df_dels.loc[(((df_dels["indicator_name"] == 'Military expenditure') &
                           (df_dels["date"] < 1981))) & 
                           df_dels["value"].isnull()].index, inplace=True)


# Drop Null rows for proportion of seats held by women in national parliaments before 1997
df_dels.drop(df_dels.loc[(((df_dels["indicator_name"] == 'Proportion of seats held by women in national parliaments') &
                           (df_dels["date"] < 1997))) & 
                           df_dels["value"].isnull()].index, inplace=True)


# Drop Null rows for scientific technical journal articles before 1996
df_dels.drop(df_dels.loc[(((df_dels["indicator_name"] == 'Scientific technical journal articles') &
                           (df_dels["date"] < 1996))) & 
                           df_dels["value"].isnull()].index, inplace=True)


# Drop Null rows for mortality caused by road traffic before 2000
df_dels.drop(df_dels.loc[(((df_dels["indicator_name"] == 'Mortality caused by road traffic') &
                           (df_dels["date"] < 2000))) & 
                           df_dels["value"].isnull()].index, inplace=True)

# Drop Null rows for access to electricity before 1994
df_dels.drop(df_dels.loc[(((df_dels["indicator_name"] == 'Access to electricity') &
                           (df_dels["date"] < 1994))) & 
                           df_dels["value"].isnull()].index, inplace=True)


# Drop Null rows for access to clean fuels and technologies for cooking before 2000
df_dels.drop(df_dels.loc[(((df_dels["indicator_name"] == 'Access to clean fuels and technologies for cooking') &
                           (df_dels["date"] < 2000))) & 
                           df_dels["value"].isnull()].index, inplace=True)

# Drop Null rows for refugee population, forest area and agricultural methane emissions before 2000
df_dels.drop(df_dels.loc[((df_dels["indicator_name"] == 'Refugee population') | 
                          (df_dels["indicator_name"] == 'Forest area') | 
                          (df_dels["indicator_name"] == 'CO2 emissions') | 
                          (df_dels["indicator_name"] == 'Renewable energy consumption % stagnates') | 
                          ((df_dels["indicator_name"] == 'Agricultural methane emissions') & 
                           (df_dels["date"] < 1990))) & 
                           df_dels["value"].isnull()].index, inplace=True)

# Drop Null rows for Energy use before 1971
df_dels.drop(df_dels.loc[(((df_dels["indicator_name"] == 'Energy use') &
                           (df_dels["date"] < 1971))) & 
                           df_dels["value"].isnull()].index, inplace=True)

# Drop Null rows for Total greenhouse gas emissions before 1991
df_dels.drop(df_dels.loc[(((df_dels["indicator_name"] == 'Total greenhouse gas emissions') &
                           (df_dels["date"] < 1991))) & 
                           df_dels["value"].isnull()].index, inplace=True)

# Drop Null rows for Population density before 1961
df_dels.drop(df_dels.loc[(((df_dels["indicator_name"] == 'Population density') &
                           (df_dels["date"] < 1961))) & 
                           df_dels["value"].isnull()].index, inplace=True)

# %%
# Show remaining Nulls
df_dels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 212166 entries, 40 to 426841
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   country         212166 non-null  object
#  1   date            212166 non-null  int64
#  2   indicator_name  212166 non-null  object
#  3   value           199716 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 8.1+ MB

# %% [markdown]
# # Third step filling with linear regression
# Check the Proportion of not Null Values to Null Values. If the not Null Data for an country-indicator is 70% or higher the Null Values will be filled by a Linear Regression.
# If a countries Proportion of Not Nulls is lower than 30% the indicator will be deleted for the country

# %%
# List of all indicators 
indicators = df_dels['indicator_name'].unique()

# List of all countries
countries = df_dels['country'].unique()

# Loop over all countries and indicators
for country in countries:
    for indicator in indicators:

        # Calculate the proportian of Nulls 
        # Count not null values for the specified country and indicator
        not_null_count = df_dels.loc[(df_dels['country'] == country) & (df_dels['indicator_name'] == indicator), 'value'].count()

        # Count total values for the specified country and indicator
        total_count = df_dels.loc[(df_dels['country'] == country) & (df_dels['indicator_name'] == indicator), 'value'].size

        # Calculate the proportion of not null
        not_null_proportion = not_null_count/total_count



        # If the not null proportian for a country is less then 30% delete the indicator for the country
        if not_null_proportion < 0.3: 
            # Create a string for the deleted country indicator
            country_indi = country + '_' + indicator
            # Store deleted country indicator 
            country_del_indicators = country_del_indicators + [country_indi]
           
            # Remove the rows corresponding to the indicator for the country
            df_dels = df_dels.loc[(df_dels["country"] != country) | (df_dels["indicator_name"] != indicator)]
            print(country_indi)

        # If the not Null proportian for a country is higher then 70% fill the Nulls with a Linear Regression
        elif not_null_proportion >= 0.70: 
            df_dels.loc[(df_dels['country'] == country) & (df_dels['indicator_name'] == indicator), 'value'].interpolate(method='linear', inplace=True)
# Out:
# /var/folders/cx/n48bpdt164v8z8lqdrk84fmw0000gn/T/ipykernel_48796/1487486380.py:19: RuntimeWarning: invalid value encountered in scalar divide
#   not_null_proportion = not_null_count/total_count

# %%
df_dels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 212166 entries, 40 to 426841
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   country         212166 non-null  object
#  1   date            212166 non-null  int64
#  2   indicator_name  212166 non-null  object
#  3   value           199716 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 8.1+ MB

# %% [markdown]
# # Fourth Step: Deleting the remaining NA's
# If there are still empty rows within the Dataframe simply drop the rows

# %%
# Drop remaining NA's
df_cleaned = df_dels.dropna()

# %%
# Store csv
#df_cleaned.to_csv('/Users/kevingiesen/Library/Mobile Documents/com~apple~CloudDocs/BIPM Master/Semester 2/Big Data/Big Data Project 2/SS23-BIPM-Big-Data-Group-KMJ-Do-Gooders/app/world_bank_data_clean_v2.csv', index=False)
